# %%
# %pdb

import numpy as np
import pandas as pd

d = pd.read_csv("data/nomes.csv")

d.head()

d.describe()
# Out:
# Automatic pdb calling has been turned ON
#        frequency_female  frequency_male  frequency_total  frequency_group  \
# count      6.048400e+04    5.093200e+04     1.007870e+05     1.007870e+05
# mean       1.529848e+03    1.740660e+03     1.797718e+03     1.766752e+04
# std        5.116376e+04    3.856265e+04     4.837138e+04     1.783261e+05
# min        2.000000e+01    2.000000e+01     2.000000e+01     2.000000e+01
# 25%        3.200000e+01    3.200000e+01     3.300000e+01     8.900000e+01
# 50%        6.300000e+01    6.200000e+01     6.700000e+01     3.520000e+02
# 75%        1.790000e+02    1.770000e+02     1.970000e+02     2.254000e+03
# max        1.169474e+07    5.732508e+06     1.173413e+07     1.174166e+07
#
#                ratio
# count  100787.000000
# mean        0.981382
# std         0.076555
# min         0.500000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
d.groupby(['first_name']).count()
# Out:
#              alternative_names  classification  frequency_female  \
# first_name
# AABRAO                       1               1                 0
# AADRIANA                     1               1                 1
# AADRIANO                     1               1                 0
# AAILTON                      1               1                 0
# AALAN                        1               1                 0
# AALESSANDRA                  1               1                 1
# AALESSANDRO                  1               1                 0
# AALEX                        1               1                 0
# AALEXANDRE                   1               1                 0
# AALINE                       1               1                 1
# AALIYAH                      1               1                 1
# AAMANDA                      1               1                 1
# AAMARIA                      1               1                 1
# ...
